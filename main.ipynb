# %%
# Link of Competition  :   https://www.kaggle.com/competitions/rossmann-store-sales

# %%
import pandas as pd 
import numpy as np 
from ydata_profiling import ProfileReport

# %%
def Overview(data) :
    profile = ProfileReport(data)
    profile.to_file("Analysis.html")

train_data = pd.read_csv('data/train.csv', low_memory=False)
store_data = pd.read_csv('data/store.csv')

# %%
train_data
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo
# 0            1          5  2015-07-31   5263        555     1      1  \
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday
# 0                  0              1
# 1                  0              1
# ...

# %%
store_data
# Out:
#       Store StoreType Assortment  CompetitionDistance
# 0         1         c          a               1270.0  \
# 1         2         a          a                570.0
# 2         3         a          a              14130.0
# 3         4         c          c                620.0
# 4         5         a          a              29910.0
# ...     ...       ...        ...                  ...
# 1110   1111         a          a               1900.0
# 1111   1112         c          c               1880.0
# 1112   1113         a          c               9260.0
# 1113   1114         a          c                870.0
# 1114   1115         d          c               5350.0
#
#       CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2
# 0                           9.0                    2008.0       0  \
# 1                          11.0                    2007.0       1
# 2                          12.0                    2006.0       1
# ...

# %%
data = pd.merge(train_data, store_data, how='left')

# %%
data
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo
# 0            1          5  2015-07-31   5263        555     1      1  \
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance
# ...

# %%
data = data[data['Open'] == 1]

# %%
data.shape
# Out:
# (844392, 18)

# %%
# Taking Overview of data using ydata_profiling

# Overview(data)

# %%
# Missing values  
data.isna().mean().sort_values(ascending=False)*100
# Out:
# PromoInterval                50.131574
# Promo2SinceYear              50.131574
# Promo2SinceWeek              50.131574
# CompetitionOpenSinceYear     31.812120
# CompetitionOpenSinceMonth    31.812120
# CompetitionDistance           0.258884
# DayOfWeek                     0.000000
# Promo2                        0.000000
# Assortment                    0.000000
# Store                         0.000000
# SchoolHoliday                 0.000000
# StateHoliday                  0.000000
# Promo                         0.000000
# Open                          0.000000
# Customers                     0.000000
# Sales                         0.000000
# Date                          0.000000
# StoreType                     0.000000
# dtype: float64

# %%
# There is very high percentage of missing value in few columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 844392 entries, 0 to 1017190
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Store                      844392 non-null  int64
#  1   DayOfWeek                  844392 non-null  int64
#  2   Date                       844392 non-null  object
#  3   Sales                      844392 non-null  int64
#  4   Customers                  844392 non-null  int64
#  5   Open                       844392 non-null  int64
#  6   Promo                      844392 non-null  int64
#  7   StateHoliday               844392 non-null  object
#  8   SchoolHoliday              844392 non-null  int64
#  9   StoreType                  844392 non-null  object
#  10  Assortment                 844392 non-null  object
#  11  CompetitionDistance        842206 non-null  float64
#  12  CompetitionOpenSinceMonth  575773 non-null  float64
# ...

# %%
# Changing the data of columns

# Converting in datetime format

data['Date'] = pd.to_datetime(data['Date'])
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_7320\4111587384.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Date'] = pd.to_datetime(data['Date'])

# %%
max(data.Store)

# So Convert it into int32

data['Store'] = data.Store.astype('int32')
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_7320\1501200224.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Store'] = data.Store.astype('int32')

# %%
def ConvertDataType(data) : 
    for column in data.columns :
        if data[column].dtype == 'int64' :
            if max(data[column]) <= 8000 :
                data[column] = data[column].astype('int32')
        elif data[column].dtype == 'float64' :
            if max(data[column]) <= 8000 :
                data[column] = data[column].astype('float32')
    return data

# %%
data = ConvertDataType(data)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_7320\2501077812.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data[column].astype('int32')
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_7320\2501077812.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data[column].astype('int32')
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_7320\2501077812.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 844392 entries, 0 to 1017190
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Store                      844392 non-null  int32
#  1   DayOfWeek                  844392 non-null  int32
#  2   Date                       844392 non-null  datetime64[ns]
#  3   Sales                      844392 non-null  int64
#  4   Customers                  844392 non-null  int32
#  5   Open                       844392 non-null  int32
#  6   Promo                      844392 non-null  int32
#  7   StateHoliday               844392 non-null  object
#  8   SchoolHoliday              844392 non-null  int32
#  9   StoreType                  844392 non-null  object
#  10  Assortment                 844392 non-null  object
#  11  CompetitionDistance        842206 non-null  float64
#  12  CompetitionOpenSinceMonth  575773 non-null  float32
# ...

# %%
# Time Series Data analysis
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# %%
sns.set(rc={'figure.figsize': (8, 6)})
# sns.lineplot(x='Date', y='Sales', data=data)

# %%
data['Date'].dt.year.unique()
# Out:
# array([2015, 2014, 2013])

# %%
data['Year'] = data['Date'].dt.year
data['Month'] = data['Date'].dt.month

monthly_average_sales = data.groupby(['Year', 'Month'])['Sales'].mean().reset_index()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_7320\2760568774.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Year'] = data['Date'].dt.year
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_7320\2760568774.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Month'] = data['Date'].dt.month

# %%
monthly_average_sales
# Out:
#     Year  Month        Sales
# 0   2013      1  6239.641380
# 1   2013      2  6428.597796
# 2   2013      3  7212.834110
# 3   2013      4  6579.319656
# 4   2013      5  7076.217960
# 5   2013      6  6467.051428
# 6   2013      7  6923.154611
# 7   2013      8  6595.927627
# 8   2013      9  6363.388121
# 9   2013     10  6473.347016
# 10  2013     11  6904.509503
# 11  2013     12  8613.455299
# 12  2014      1  6539.402563
# 13  2014      2  6678.038182
# 14  2014      3  6654.021442
# 15  2014      4  7226.782207
# 16  2014      5  6948.119518
# 17  2014      6  7250.660066
# 18  2014      7  6891.479689
# 19  2014      8  6714.305191
# 20  2014      9  6756.588279
# 21  2014     10  6757.320303
# 22  2014     11  7539.603854
# 23  2014     12  8603.805210
# 24  2015      1  6913.177694
# 25  2015      2  6660.270408
# 26  2015      3  7071.240818
# 27  2015      4  7349.110170
# 28  2015      5  7308.496793
# 29  2015      6  7295.618795
# 30  2015      7  7033.344905

# %%
sns.set(rc={'figure.figsize': (10, 8)})

sns.lineplot(data=monthly_average_sales, x='Year', y='Sales', label='Average')

plt.xlabel('Date')
plt.ylabel('Sales')
plt.legend()
plt.show()

# %%
daily_data = data.resample('D', on='Date').sum()['Sales']

# %%
monthly_data_mean = daily_data.rolling(window=30).mean()

# %%
weekly_data_mean = daily_data.rolling(window=7).mean()

# %%
sns.lineplot(data=daily_data, x=daily_data.index, y=daily_data.values, label = "Original Data")
sns.lineplot(data=weekly_data_mean, x=weekly_data_mean.index, y= weekly_data_mean.values, label="Average Weekly Values")
sns.lineplot(data=monthly_data_mean, x=monthly_data_mean.index, y=monthly_data_mean.values, label = "Average Monthly Data")

# %%
# Looking the sales of every month 

yearly_data = data.resample('M', on='Date').sum()['Sales'].reset_index()
yearly_data['year'] = yearly_data['Date'].dt.year
for year in list(yearly_data['year'].unique()) :
    year_on = yearly_data[yearly_data['Date'].dt.year == year]
    sns.lineplot(data=year_on, x=year_on['Date'].dt.month, y='Sales', label=str(year))

# %%
# Other Multicollerity Analysis

# px.histogram(data, x='Sales', y='CompetitionDistance', color='StateHoliday')

# %%
data.columns

# %%
# px.histogram(data, x='Sales', y='Customers', color='StoreType')

# %%
# Store B has more sales

# %%
# px.histogram(data, x='Sales', y='Customers', color='Promo')

# %%
# px.scatter(data, x='Sales', y='Customers', color='CompetitionOpenSinceMonth')

# %%
# px.strip(data, x='Sales', y='Customers')
